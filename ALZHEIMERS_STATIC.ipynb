# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st
from scipy.stats import linregress
import os

# %%
dementia_df = pd.read_csv("Resources/dementia_patients_health_data.csv")
dementia_df
# Out:
#      Diabetic  AlcoholLevel  HeartRate  BloodOxygenLevel  BodyTemperature  \
# 0           1      0.084974         98         96.230743        36.224852
# 1           0      0.016973         78         93.032122        36.183874
# 2           0      0.009000         89         93.566504        37.326321
# 3           0      0.086437         60         93.906510        37.030620
# 4           1      0.150747         67         97.508994        36.062121
# ..        ...           ...        ...               ...              ...
# 995         1      0.081825         87         93.851963        36.495134
# 996         1      0.145249         97         94.522391        36.270804
# 997         1      0.073692         65         98.578388        37.065703
# 998         0      0.037347         71         91.298580        37.037202
# 999         0      0.085969         90         95.522825        36.026748
#
#         Weight  MRI_Delay Prescription  Dosage in mg  Age  ...  \
# ...

# %%
dementia_df.value_counts()
# Out:
# Diabetic  AlcoholLevel  HeartRate  BloodOxygenLevel  BodyTemperature  Weight     MRI_Delay  Prescription  Dosage in mg  Age  Education_Level   Dominant_Hand  Gender  Family_History  Smoking_Status  APOE_ε4   Physical_Activity  Depression_Status  Cognitive_Test_Scores  Medication_History  Nutrition_Diet      Sleep_Quality  Chronic_Health_Conditions  Dementia
# 0         0.000414      71         91.909421         36.014734        71.346967  2.600132   Galantamine   12.0          75   Primary School    Right          Female  Yes             Former Smoker   Negative  Sedentary          No                 7                      Yes                 Balanced Diet       Good           Hypertension               1           1
# ...

# %%
dementia_df["Sleep_Quality"].unique()
# Out:
# array(['Poor', 'Good'], dtype=object)

# %%
dementia_df["MRI_Delay"].max()
# Out:
# 59.95759863692137
