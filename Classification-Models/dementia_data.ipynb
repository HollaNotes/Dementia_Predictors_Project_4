# %%
# Dependencies and Setup
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
import os
from contextlib import redirect_stdout
# Out:
# WARNING:tensorflow:From c:\Users\Hansle Goh\anaconda3\envs\dev\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
pd.set_option('display.max_columns', None)

dementia_df = pd.read_csv("Resources/dementia_patients_health_data.csv")
dementia_df
# Out:
#      Diabetic  AlcoholLevel  HeartRate  BloodOxygenLevel  BodyTemperature  \
# 0           1      0.084974         98         96.230743        36.224852
# 1           0      0.016973         78         93.032122        36.183874
# 2           0      0.009000         89         93.566504        37.326321
# 3           0      0.086437         60         93.906510        37.030620
# 4           1      0.150747         67         97.508994        36.062121
# ..        ...           ...        ...               ...              ...
# 995         1      0.081825         87         93.851963        36.495134
# 996         1      0.145249         97         94.522391        36.270804
# 997         1      0.073692         65         98.578388        37.065703
# 998         0      0.037347         71         91.298580        37.037202
# 999         0      0.085969         90         95.522825        36.026748
#
#         Weight  MRI_Delay Prescription  Dosage in mg  Age   Education_Level  \
# 0    57.563978  36.421028          NaN           NaN   60    Primary School
# 1    56.832335  31.157633  Galantamine          12.0   61  Secondary School
# 2    59.759066  37.640435          NaN           NaN   69    Primary School
# 3    58.266471  50.673992    Donepezil          23.0   78  Secondary School
# 4    67.705027  27.810601    Memantine          20.0   77  Secondary School
# ..         ...        ...          ...           ...  ...               ...
# 995  50.380106  42.318663    Donepezil          10.0   88    Diploma/Degree
# 996  94.006484  52.812568          NaN           NaN   80    Primary School
# 997  80.088613  13.640229          NaN           NaN   67    Primary School
# 998  95.322210  17.445715    Memantine          20.0   62         No School
# 999  57.671455  30.011838          NaN           NaN   80  Secondary School
#
#     Dominant_Hand  Gender Family_History  Smoking_Status   APOE_ε4  \
# 0            Left  Female             No  Current Smoker  Negative
# 1           Right    Male             No   Former Smoker  Positive
# 2           Right    Male            Yes   Former Smoker  Negative
# 3            Left  Female            Yes    Never Smoked  Negative
# 4           Right    Male            Yes    Never Smoked  Positive
# ..            ...     ...            ...             ...       ...
# 995          Left    Male            Yes    Never Smoked  Positive
# 996          Left  Female             No    Never Smoked  Negative
# 997         Right  Female             No    Never Smoked  Positive
# 998          Left    Male            Yes    Never Smoked  Positive
# 999          Left  Female            Yes    Never Smoked  Positive
#
#      Physical_Activity Depression_Status  Cognitive_Test_Scores  \
# 0            Sedentary                No                     10
# 1    Moderate Activity                No                      1
# 2    Moderate Activity                No                      8
# 3        Mild Activity               Yes                      5
# 4        Mild Activity                No                      0
# ..                 ...               ...                    ...
# 995      Mild Activity                No                      5
# 996  Moderate Activity                No                      9
# 997          Sedentary                No                      8
# 998          Sedentary               Yes                      2
# 999      Mild Activity                No                     10
#
#     Medication_History      Nutrition_Diet Sleep_Quality  \
# 0                   No       Low-Carb Diet          Poor
# 1                  Yes       Low-Carb Diet          Poor
# 2                   No  Mediterranean Diet          Poor
# 3                  Yes       Balanced Diet          Poor
# 4                  Yes       Low-Carb Diet          Good
# ..                 ...                 ...           ...
# 995                 No       Balanced Diet          Poor
# 996                Yes       Low-Carb Diet          Poor
# 997                Yes       Balanced Diet          Good
# 998                 No       Low-Carb Diet          Good
# 999                Yes  Mediterranean Diet          Good
#
#     Chronic_Health_Conditions  Dementia
# 0                    Diabetes         0
# 1               Heart Disease         1
# 2               Heart Disease         0
# 3                Hypertension         1
# 4                    Diabetes         1
# ..                        ...       ...
# 995                  Diabetes         1
# 996                  Diabetes         0
# 997                  Diabetes         0
# 998                       NaN         1
# 999             Heart Disease         0
#
# [1000 rows x 24 columns]

# %% [markdown]
# # Preprocessing the Data

# %%
# Drop unimportant 'Prescription' and 'Dosage in mg' columns
dementia_df.drop(columns=['Prescription', 'Dosage in mg'], inplace=True)
dementia_df.head()
# Out:
#    Diabetic  AlcoholLevel  HeartRate  BloodOxygenLevel  BodyTemperature  \
# 0         1      0.084974         98         96.230743        36.224852
# 1         0      0.016973         78         93.032122        36.183874
# 2         0      0.009000         89         93.566504        37.326321
# 3         0      0.086437         60         93.906510        37.030620
# 4         1      0.150747         67         97.508994        36.062121
#
#       Weight  MRI_Delay  Age   Education_Level Dominant_Hand  Gender  \
# 0  57.563978  36.421028   60    Primary School          Left  Female
# 1  56.832335  31.157633   61  Secondary School         Right    Male
# 2  59.759066  37.640435   69    Primary School         Right    Male
# 3  58.266471  50.673992   78  Secondary School          Left  Female
# 4  67.705027  27.810601   77  Secondary School         Right    Male
#
#   Family_History  Smoking_Status   APOE_ε4  Physical_Activity  \
# 0             No  Current Smoker  Negative          Sedentary
# 1             No   Former Smoker  Positive  Moderate Activity
# 2            Yes   Former Smoker  Negative  Moderate Activity
# 3            Yes    Never Smoked  Negative      Mild Activity
# 4            Yes    Never Smoked  Positive      Mild Activity
#
#   Depression_Status  Cognitive_Test_Scores Medication_History  \
# 0                No                     10                 No
# 1                No                      1                Yes
# 2                No                      8                 No
# 3               Yes                      5                Yes
# 4                No                      0                Yes
#
#        Nutrition_Diet Sleep_Quality Chronic_Health_Conditions  Dementia
# 0       Low-Carb Diet          Poor                  Diabetes         0
# 1       Low-Carb Diet          Poor             Heart Disease         1
# 2  Mediterranean Diet          Poor             Heart Disease         0
# 3       Balanced Diet          Poor              Hypertension         1
# 4       Low-Carb Diet          Good                  Diabetes         1

# %%
# Encoding the binary columns using a custom function
binary_cols = ["Dominant_Hand", "Gender", "Family_History", "APOE_ε4", "Depression_Status", "Medication_History", "Sleep_Quality"]

def encode_binary(bin):
    if bin in ("Left", "Female", "Yes", "Positive", "Good"):
        return 1
    else:
        return 0

# Call the encode_binary function on the binary columns
for col in binary_cols:
    dementia_df[col] = dementia_df[col].apply(encode_binary)
dementia_df.head()
# Out:
#    Diabetic  AlcoholLevel  HeartRate  BloodOxygenLevel  BodyTemperature  \
# 0         1      0.084974         98         96.230743        36.224852
# 1         0      0.016973         78         93.032122        36.183874
# 2         0      0.009000         89         93.566504        37.326321
# 3         0      0.086437         60         93.906510        37.030620
# 4         1      0.150747         67         97.508994        36.062121
#
#       Weight  MRI_Delay  Age   Education_Level  Dominant_Hand  Gender  \
# 0  57.563978  36.421028   60    Primary School              1       1
# 1  56.832335  31.157633   61  Secondary School              0       0
# 2  59.759066  37.640435   69    Primary School              0       0
# 3  58.266471  50.673992   78  Secondary School              1       1
# 4  67.705027  27.810601   77  Secondary School              0       0
#
#    Family_History  Smoking_Status  APOE_ε4  Physical_Activity  \
# 0               0  Current Smoker        0          Sedentary
# 1               0   Former Smoker        1  Moderate Activity
# 2               1   Former Smoker        0  Moderate Activity
# 3               1    Never Smoked        0      Mild Activity
# 4               1    Never Smoked        1      Mild Activity
#
#    Depression_Status  Cognitive_Test_Scores  Medication_History  \
# 0                  0                     10                   0
# 1                  0                      1                   1
# 2                  0                      8                   0
# 3                  1                      5                   1
# 4                  0                      0                   1
#
#        Nutrition_Diet  Sleep_Quality Chronic_Health_Conditions  Dementia
# 0       Low-Carb Diet              0                  Diabetes         0
# 1       Low-Carb Diet              0             Heart Disease         1
# 2  Mediterranean Diet              0             Heart Disease         0
# 3       Balanced Diet              0              Hypertension         1
# 4       Low-Carb Diet              1                  Diabetes         1

# %%
# Convert categorical data to numeric with `pd.get_dummies`
categorical_cols = dementia_df.columns.drop(labels=['Diabetic', 'AlcoholLevel', 'HeartRate', 'BloodOxygenLevel', 'BodyTemperature', 'Weight', 'MRI_Delay', 'Age', 'Cognitive_Test_Scores', 'Dementia'] + binary_cols)
for col in categorical_cols:
    dementia_df = pd.concat([dementia_df, pd.get_dummies(dementia_df[col])], axis=1)
    dementia_df.drop(columns=col, inplace=True)

dementia_df.head()
# Out:
#    Diabetic  AlcoholLevel  HeartRate  BloodOxygenLevel  BodyTemperature  \
# 0         1      0.084974         98         96.230743        36.224852
# 1         0      0.016973         78         93.032122        36.183874
# 2         0      0.009000         89         93.566504        37.326321
# 3         0      0.086437         60         93.906510        37.030620
# 4         1      0.150747         67         97.508994        36.062121
#
#       Weight  MRI_Delay  Age  Dominant_Hand  Gender  Family_History  APOE_ε4  \
# 0  57.563978  36.421028   60              1       1               0        0
# 1  56.832335  31.157633   61              0       0               0        1
# 2  59.759066  37.640435   69              0       0               1        0
# 3  58.266471  50.673992   78              1       1               1        0
# 4  67.705027  27.810601   77              0       0               1        1
#
#    Depression_Status  Cognitive_Test_Scores  Medication_History  \
# 0                  0                     10                   0
# 1                  0                      1                   1
# 2                  0                      8                   0
# 3                  1                      5                   1
# 4                  0                      0                   1
#
#    Sleep_Quality  Dementia  Diploma/Degree  No School  Primary School  \
# 0              0         0           False      False            True
# 1              0         1           False      False           False
# 2              0         0           False      False            True
# 3              0         1           False      False           False
# 4              1         1           False      False           False
#
#    Secondary School  Current Smoker  Former Smoker  Never Smoked  \
# 0             False            True          False         False
# 1              True           False           True         False
# 2             False           False           True         False
# 3              True           False          False          True
# 4              True           False          False          True
#
#    Mild Activity  Moderate Activity  Sedentary  Balanced Diet  Low-Carb Diet  \
# 0          False              False       True          False           True
# 1          False               True      False          False           True
# 2          False               True      False          False          False
# 3           True              False      False           True          False
# 4           True              False      False          False           True
#
#    Mediterranean Diet  Diabetes  Heart Disease  Hypertension
# 0               False      True          False         False
# 1               False     False           True         False
# 2                True     False           True         False
# 3               False     False          False          True
# 4               False      True          False         False

# %%
# Drop 'Diabetes' column as it duplicates the 'Diabetic' column
print(dementia_df[['Diabetic', 'Diabetes']].value_counts())
dementia_df.drop(columns='Diabetes', inplace=True)
dementia_df.head()
# Out:
# Diabetic  Diabetes
# 1         True        513
# 0         False       487
# Name: count, dtype: int64
#    Diabetic  AlcoholLevel  HeartRate  BloodOxygenLevel  BodyTemperature  \
# 0         1      0.084974         98         96.230743        36.224852
# 1         0      0.016973         78         93.032122        36.183874
# 2         0      0.009000         89         93.566504        37.326321
# 3         0      0.086437         60         93.906510        37.030620
# 4         1      0.150747         67         97.508994        36.062121
#
#       Weight  MRI_Delay  Age  Dominant_Hand  Gender  Family_History  APOE_ε4  \
# 0  57.563978  36.421028   60              1       1               0        0
# 1  56.832335  31.157633   61              0       0               0        1
# 2  59.759066  37.640435   69              0       0               1        0
# 3  58.266471  50.673992   78              1       1               1        0
# 4  67.705027  27.810601   77              0       0               1        1
#
#    Depression_Status  Cognitive_Test_Scores  Medication_History  \
# 0                  0                     10                   0
# 1                  0                      1                   1
# 2                  0                      8                   0
# 3                  1                      5                   1
# 4                  0                      0                   1
#
#    Sleep_Quality  Dementia  Diploma/Degree  No School  Primary School  \
# 0              0         0           False      False            True
# 1              0         1           False      False           False
# 2              0         0           False      False            True
# 3              0         1           False      False           False
# 4              1         1           False      False           False
#
#    Secondary School  Current Smoker  Former Smoker  Never Smoked  \
# 0             False            True          False         False
# 1              True           False           True         False
# 2             False           False           True         False
# 3              True           False          False          True
# 4              True           False          False          True
#
#    Mild Activity  Moderate Activity  Sedentary  Balanced Diet  Low-Carb Diet  \
# 0          False              False       True          False           True
# 1          False               True      False          False           True
# 2          False               True      False          False          False
# 3           True              False      False           True          False
# 4           True              False      False          False           True
#
#    Mediterranean Diet  Heart Disease  Hypertension
# 0               False          False         False
# 1               False           True         False
# 2                True           True         False
# 3               False          False          True
# 4               False          False         False

# %%
# Assign target variable and features
y = dementia_df['Dementia']
X = dementia_df.drop(columns='Dementia')

# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=3)

# %%
# Preprocess numerical data for neural network

# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# # Deep Learning Model

# %%
# Create a method that creates a new Sequential model with hyperparameter options
def create_model(hp):
    nn_model = tf.keras.models.Sequential()

    # Allow kerastuner to decide which activation function to use in hidden layers
    activation = hp.Choice('activation',['relu', 'leaky_relu'])
    activation_last = hp.Choice('activation_last',['sigmoid', 'tanh'])
    
    # Allow kerastuner to decide number of neurons in first layer
    nn_model.add(tf.keras.layers.Dense(units=hp.Int('first_units',
        min_value=1,
        max_value=500,
        step=5), activation=activation, input_dim=len(X_train.columns)))

    # Allow kerastuner to decide number of hidden layers and neurons in hidden layers
    for i in range(hp.Int('num_layers', 1, 10)):
        nn_model.add(tf.keras.layers.Dense(units=hp.Int('units_' + str(i),
            min_value=1,
            max_value=500,
            step=5),
            activation=activation))
    
    nn_model.add(tf.keras.layers.Dense(units=1, activation=activation_last))

    # Compile the model
    nn_model.compile(loss="binary_crossentropy", optimizer='adam', metrics=["accuracy"])
    
    return nn_model

# %%
# Import the kerastuner library
import keras_tuner as kt

tuner = kt.Hyperband(
    create_model,
    objective="val_accuracy",
    max_epochs=20,
    hyperband_iterations=2,
    directory=os.path.normpath('C:/'),
    project_name='dementia_keras_tuner',
    overwrite=True)

# %%
# Run the kerastuner search for best hyperparameters
tuner.search(X_train_scaled,y_train,epochs=20,validation_data=(X_test_scaled,y_test))
# Out:
# Trial 60 Complete [00h 00m 08s]
# val_accuracy: 0.9800000190734863
#
# Best val_accuracy So Far: 1.0
# Total elapsed time: 00h 04m 18s

# %%
# Get top 10 model hyperparameters and print the values
from pprint import pprint
top_hps = tuner.get_best_hyperparameters(10)
for param in top_hps:
    pprint(param.values)
    print('-'*40)
# Out:
# {'activation': 'leaky_relu',
#  'activation_last': 'tanh',
#  'first_units': 436,
#  'num_layers': 7,
#  'tuner/bracket': 2,
#  'tuner/epochs': 20,
#  'tuner/initial_epoch': 7,
#  'tuner/round': 2,
#  'tuner/trial_id': '0012',
#  'units_0': 271,
#  'units_1': 151,
#  'units_2': 66,
#  'units_3': 181,
#  'units_4': 271,
#  'units_5': 121,
#  'units_6': 1,
#  'units_7': 271,
#  'units_8': 6,
#  'units_9': 411}
# ----------------------------------------
# {'activation': 'relu',
#  'activation_last': 'sigmoid',
#  'first_units': 246,
#  'num_layers': 6,
#  'tuner/bracket': 1,
#  'tuner/epochs': 7,
#  'tuner/initial_epoch': 0,
#  'tuner/round': 0,
#  'units_0': 186,
#  'units_1': 491,
#  'units_2': 226,
#  'units_3': 76,
#  'units_4': 291,
#  'units_5': 301,
#  'units_6': 396,
#  'units_7': 146,
#  'units_8': 356,
#  'units_9': 41}
# ----------------------------------------
# {'activation': 'relu',
#  'activation_last': 'sigmoid',
#  'first_units': 246,
#  'num_layers': 6,
#  'tuner/bracket': 1,
#  'tuner/epochs': 20,
#  'tuner/initial_epoch': 7,
#  'tuner/round': 1,
#  'tuner/trial_id': '0049',
#  'units_0': 186,
#  'units_1': 491,
#  'units_2': 226,
#  'units_3': 76,
#  'units_4': 291,
#  'units_5': 301,
#  'units_6': 396,
#  'units_7': 146,
#  'units_8': 356,
#  'units_9': 41}
# ----------------------------------------
# {'activation': 'leaky_relu',
#  'activation_last': 'tanh',
#  'first_units': 436,
#  'num_layers': 7,
#  'tuner/bracket': 2,
#  'tuner/epochs': 3,
#  'tuner/initial_epoch': 0,
#  'tuner/round': 0,
#  'units_0': 271,
#  'units_1': 151,
#  'units_2': 66,
#  'units_3': 181,
#  'units_4': 271,
#  'units_5': 121,
#  'units_6': 1}
# ----------------------------------------
# {'activation': 'leaky_relu',
#  'activation_last': 'tanh',
#  'first_units': 436,
#  'num_layers': 7,
#  'tuner/bracket': 2,
#  'tuner/epochs': 7,
#  'tuner/initial_epoch': 3,
#  'tuner/round': 1,
#  'tuner/trial_id': '0002',
#  'units_0': 271,
#  'units_1': 151,
#  'units_2': 66,
#  'units_3': 181,
#  'units_4': 271,
#  'units_5': 121,
#  'units_6': 1,
#  'units_7': 271,
#  'units_8': 6,
#  'units_9': 411}
# ----------------------------------------
# {'activation': 'leaky_relu',
#  'activation_last': 'sigmoid',
#  'first_units': 246,
#  'num_layers': 5,
#  'tuner/bracket': 2,
#  'tuner/epochs': 20,
#  'tuner/initial_epoch': 7,
#  'tuner/round': 2,
#  'tuner/trial_id': '0013',
#  'units_0': 306,
#  'units_1': 101,
#  'units_2': 246,
#  'units_3': 191,
#  'units_4': 191,
#  'units_5': 31,
#  'units_6': 86,
#  'units_7': 6,
#  'units_8': 446,
#  'units_9': 86}
# ----------------------------------------
# {'activation': 'leaky_relu',
#  'activation_last': 'tanh',
#  'first_units': 106,
#  'num_layers': 2,
#  'tuner/bracket': 1,
#  'tuner/epochs': 20,
#  'tuner/initial_epoch': 7,
#  'tuner/round': 1,
#  'tuner/trial_id': '0018',
#  'units_0': 151,
#  'units_1': 136,
#  'units_2': 1,
#  'units_3': 106,
#  'units_4': 311,
#  'units_5': 121,
#  'units_6': 71,
#  'units_7': 191,
#  'units_8': 326,
#  'units_9': 116}
# ----------------------------------------
# {'activation': 'leaky_relu',
#  'activation_last': 'sigmoid',
#  'first_units': 436,
#  'num_layers': 4,
#  'tuner/bracket': 2,
#  'tuner/epochs': 7,
#  'tuner/initial_epoch': 3,
#  'tuner/round': 1,
#  'tuner/trial_id': '0040',
#  'units_0': 376,
#  'units_1': 126,
#  'units_2': 126,
#  'units_3': 321,
#  'units_4': 371,
#  'units_5': 266,
#  'units_6': 236,
#  'units_7': 136,
#  'units_8': 316,
#  'units_9': 246}
# ----------------------------------------
# {'activation': 'leaky_relu',
#  'activation_last': 'sigmoid',
#  'first_units': 246,
#  'num_layers': 5,
#  'tuner/bracket': 2,
#  'tuner/epochs': 7,
#  'tuner/initial_epoch': 3,
#  'tuner/round': 1,
#  'tuner/trial_id': '0007',
#  'units_0': 306,
#  'units_1': 101,
#  'units_2': 246,
#  'units_3': 191,
#  'units_4': 191,
#  'units_5': 31,
#  'units_6': 86,
#  'units_7': 6,
#  'units_8': 446,
#  'units_9': 86}
# ----------------------------------------
# {'activation': 'relu',
#  'activation_last': 'tanh',
#  'first_units': 351,
#  'num_layers': 5,
#  'tuner/bracket': 2,
#  'tuner/epochs': 7,
#  'tuner/initial_epoch': 3,
#  'tuner/round': 1,
#  'tuner/trial_id': '0005',
#  'units_0': 286,
#  'units_1': 16,
#  'units_2': 326,
#  'units_3': 146,
#  'units_4': 96,
#  'units_5': 326,
#  'units_6': 386,
#  'units_7': 431,
#  'units_8': 26,
#  'units_9': 201}
# ----------------------------------------

# %%
# Evaluate the top 3 models against the test dataset
top_models = tuner.get_best_models(3)
for model in top_models:
    model_loss, model_accuracy = model.evaluate(X_test_scaled,y_test,verbose=2)
    print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
    print('-'*80)
# Out:
# 8/8 - 0s - loss: 0.0108 - accuracy: 1.0000 - 252ms/epoch - 32ms/step
# Loss: 0.010760552249848843, Accuracy: 1.0
# --------------------------------------------------------------------------------
# 8/8 - 0s - loss: 0.0198 - accuracy: 0.9960 - 240ms/epoch - 30ms/step
# Loss: 0.01979454979300499, Accuracy: 0.9959999918937683
# --------------------------------------------------------------------------------
# 8/8 - 0s - loss: 0.0177 - accuracy: 0.9960 - 280ms/epoch - 35ms/step
# Loss: 0.017714032903313637, Accuracy: 0.9959999918937683
# --------------------------------------------------------------------------------

# %%
best_model = tuner.get_best_models()[0]
best_model.summary()
# Out:
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.3
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.4
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.5
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.6
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.7
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.8
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.9
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.10
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.11
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.12
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.13
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.14
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.15
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.16
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.17
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.18
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.19
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.20
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.21
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.22
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.23
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.24
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.3
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.4
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.5
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.6
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.7
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.8
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.9
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.10
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.11
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.12
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.3
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.4
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.5
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.6
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.7
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.8
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.9
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.10
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.11
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.12
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.3
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.4
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.5
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.6
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.7
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.8
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.9
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.10
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.11
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.12
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.3
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.4
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.5
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.6
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.7
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.8
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.9
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.10
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.11
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.12
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.3
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.4
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.5
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.6
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.7
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.8
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.9
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.10
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.11
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.12
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.13
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.14
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.15
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.16
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.17
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.18
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.19
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.20
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.21
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.22
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.23
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.24
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 436)               13952
#
#  dense_1 (Dense)             (None, 271)               118427
#
#  dense_2 (Dense)             (None, 151)               41072
#
#  dense_3 (Dense)             (None, 66)                10032
#
#  dense_4 (Dense)             (None, 181)               12127
#
#  dense_5 (Dense)             (None, 271)               49322
#
#  dense_6 (Dense)             (None, 121)               32912
#
#  dense_7 (Dense)             (None, 1)                 122
#
#  dense_8 (Dense)             (None, 1)                 2
#
# =================================================================
# Total params: 277968 (1.06 MB)
# Trainable params: 277968 (1.06 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Save the model's summary to a txt file
with open('best_model_summary.txt', 'w') as f:
    with redirect_stdout(f):
        best_model.summary()

# %%
#Predict
best_hps=tuner.get_best_hyperparameters()[0]

# Build the model with the optimal hyperparameters and train it on the data for 50 epochs
hypermodel = tuner.hypermodel.build(best_hps)
history = hypermodel.fit(X_train_scaled, y_train, epochs=50)

val_acc_per_epoch = history.history['accuracy']
best_epoch = val_acc_per_epoch.index(max(val_acc_per_epoch)) + 1
print('Best epoch: %d' % (best_epoch,))
# Out:
# Epoch 1/50
# 24/24 [==============================] - 1s 3ms/step - loss: 0.6280 - accuracy: 0.6960
# Epoch 2/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1675 - accuracy: 0.9547
# Epoch 3/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1462 - accuracy: 0.9773
# Epoch 4/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1110 - accuracy: 0.9773
# Epoch 5/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0570 - accuracy: 0.9867
# Epoch 6/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0353 - accuracy: 0.9960
# Epoch 7/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0234 - accuracy: 0.9987
# Epoch 8/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0962 - accuracy: 0.9813
# Epoch 9/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0909 - accuracy: 0.9813
# Epoch 10/50
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0459 - accuracy: 0.9933
# Epoch 11/50
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0068 - accuracy: 0.9987
# Epoch 12/50
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 13/50
# 24/24 [==============================] - 0s 3ms/step - loss: 5.7558e-04 - accuracy: 1.0000
# Epoch 14/50
# 24/24 [==============================] - 0s 3ms/step - loss: 2.7616e-04 - accuracy: 1.0000
# Epoch 15/50
# 24/24 [==============================] - 0s 3ms/step - loss: 1.8139e-04 - accuracy: 1.0000
# Epoch 16/50
# 24/24 [==============================] - 0s 3ms/step - loss: 2.8078e-04 - accuracy: 1.0000
# Epoch 17/50
# 24/24 [==============================] - 0s 3ms/step - loss: 2.3497e-04 - accuracy: 1.0000
# Epoch 18/50
# 24/24 [==============================] - 0s 3ms/step - loss: 1.4885e-04 - accuracy: 1.0000
# Epoch 19/50
# 24/24 [==============================] - 0s 3ms/step - loss: 1.0269e-04 - accuracy: 1.0000
# Epoch 20/50
# 24/24 [==============================] - 0s 3ms/step - loss: 9.0701e-05 - accuracy: 1.0000
# Epoch 21/50
# 24/24 [==============================] - 0s 3ms/step - loss: 6.2246e-05 - accuracy: 1.0000
# Epoch 22/50
# 24/24 [==============================] - 0s 4ms/step - loss: 5.1616e-05 - accuracy: 1.0000
# Epoch 23/50
# 24/24 [==============================] - 0s 3ms/step - loss: 9.4637e-05 - accuracy: 1.0000
# Epoch 24/50
# 24/24 [==============================] - 0s 3ms/step - loss: 8.4192e-05 - accuracy: 1.0000
# Epoch 25/50
# 24/24 [==============================] - 0s 3ms/step - loss: 6.5326e-05 - accuracy: 1.0000
# Epoch 26/50
# 24/24 [==============================] - 0s 3ms/step - loss: 5.0699e-05 - accuracy: 1.0000
# Epoch 27/50
# 24/24 [==============================] - 0s 3ms/step - loss: 4.0801e-05 - accuracy: 1.0000
# Epoch 28/50
# 24/24 [==============================] - 0s 3ms/step - loss: 3.3656e-05 - accuracy: 1.0000
# Epoch 29/50
# 24/24 [==============================] - 0s 3ms/step - loss: 2.8569e-05 - accuracy: 1.0000
# Epoch 30/50
# 24/24 [==============================] - 0s 3ms/step - loss: 2.4937e-05 - accuracy: 1.0000
# Epoch 31/50
# 24/24 [==============================] - 0s 3ms/step - loss: 2.1882e-05 - accuracy: 1.0000
# Epoch 32/50
# 24/24 [==============================] - 0s 3ms/step - loss: 3.6687e-05 - accuracy: 1.0000
# Epoch 33/50
# 24/24 [==============================] - 0s 3ms/step - loss: 3.1000e-05 - accuracy: 1.0000
# Epoch 34/50
# 24/24 [==============================] - 0s 3ms/step - loss: 2.9077e-05 - accuracy: 1.0000
# Epoch 35/50
# 24/24 [==============================] - 0s 3ms/step - loss: 2.4164e-05 - accuracy: 1.0000
# Epoch 36/50
# 24/24 [==============================] - 0s 3ms/step - loss: 2.1047e-05 - accuracy: 1.0000
# Epoch 37/50
# 24/24 [==============================] - 0s 3ms/step - loss: 1.7932e-05 - accuracy: 1.0000
# Epoch 38/50
# 24/24 [==============================] - 0s 3ms/step - loss: 1.5628e-05 - accuracy: 1.0000
# Epoch 39/50
# 24/24 [==============================] - 0s 3ms/step - loss: 1.3830e-05 - accuracy: 1.0000
# Epoch 40/50
# 24/24 [==============================] - 0s 3ms/step - loss: 1.2409e-05 - accuracy: 1.0000
# Epoch 41/50
# 24/24 [==============================] - 0s 4ms/step - loss: 1.1308e-05 - accuracy: 1.0000
# Epoch 42/50
# 24/24 [==============================] - 0s 3ms/step - loss: 1.0291e-05 - accuracy: 1.0000
# Epoch 43/50
# 24/24 [==============================] - 0s 3ms/step - loss: 9.5583e-06 - accuracy: 1.0000
# Epoch 44/50
# 24/24 [==============================] - 0s 3ms/step - loss: 8.7249e-06 - accuracy: 1.0000
# Epoch 45/50
# 24/24 [==============================] - 0s 3ms/step - loss: 8.0691e-06 - accuracy: 1.0000
# Epoch 46/50
# 24/24 [==============================] - 0s 3ms/step - loss: 7.5271e-06 - accuracy: 1.0000
# Epoch 47/50
# 24/24 [==============================] - 0s 3ms/step - loss: 7.0630e-06 - accuracy: 1.0000
# Epoch 48/50
# 24/24 [==============================] - 0s 3ms/step - loss: 6.5424e-06 - accuracy: 1.0000
# Epoch 49/50
# 24/24 [==============================] - 0s 3ms/step - loss: 6.1478e-06 - accuracy: 1.0000
# Epoch 50/50
# 24/24 [==============================] - 0s 3ms/step - loss: 5.7519e-06 - accuracy: 1.0000
# Best epoch: 12

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = hypermodel.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 8/8 - 0s - loss: 0.0157 - accuracy: 0.9960 - 157ms/epoch - 20ms/step
# Loss: 0.01571030355989933, Accuracy: 0.9959999918937683

# %%
# Save the model to a h5 file
best_model.save('dementia_predictor.h5')

# %% [markdown]
# # Random Forest Model

# %%
# Create a random forest classifier
rf_model = RandomForestClassifier(n_estimators=500, random_state=3)

# %%
# Fitting the model
rf_model = rf_model.fit(X_train_scaled, y_train)

# %%
# Making predictions using the testing data
predictions = rf_model.predict(X_test_scaled)

# %%
# Calculating the confusion matrix
cm = confusion_matrix(y_test, predictions)
cm_df = pd.DataFrame(
    cm, index=["Actual 0", "Actual 1"], columns=["Predicted 0", "Predicted 1"]
)

# Calculating the accuracy score
acc_score = accuracy_score(y_test, predictions)

# %%
# Displaying results
print("Confusion Matrix")
display(cm_df)
print(f"Accuracy Score : {acc_score}")
print("Classification Report")
print(classification_report(y_test, predictions))
# Out:
# Confusion Matrix
#           Predicted 0  Predicted 1
# Actual 0          126            0
# Actual 1            0          124
# Accuracy Score : 1.0
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       126
#            1       1.00      1.00      1.00       124
#
#     accuracy                           1.00       250
#    macro avg       1.00      1.00      1.00       250
# weighted avg       1.00      1.00      1.00       250

# %%
# Random Forests in sklearn will automatically calculate feature importance
importances = rf_model.feature_importances_
# We can sort the features by their importance
sorted(zip(rf_model.feature_importances_, X.columns), reverse=True)
# Out:
# [(0.6002065199363934, 'Cognitive_Test_Scores'),
#  (0.135974046067188, 'Depression_Status'),
#  (0.06290366766301687, 'APOE_ε4'),
#  (0.025631588560907154, 'Current Smoker'),
#  (0.02005211951377623, 'BloodOxygenLevel'),
#  (0.01803564842427596, 'BodyTemperature'),
#  (0.017673569612568798, 'Weight'),
#  (0.017321138286324592, 'MRI_Delay'),
#  (0.01660392333193582, 'AlcoholLevel'),
#  (0.01450963911142835, 'Age'),
#  (0.012294954056091144, 'HeartRate'),
#  (0.007550648546893841, 'Former Smoker'),
#  (0.00485004790127335, 'No School'),
#  (0.0044589666404391826, 'Diploma/Degree'),
#  (0.003995053916221431, 'Never Smoked'),
#  (0.003336268948727507, 'Family_History'),
#  (0.0029439593488825664, 'Sleep_Quality'),
#  (0.0027277007641536948, 'Hypertension'),
#  (0.0027141102649234057, 'Dominant_Hand'),
#  (0.0026212866535236592, 'Mild Activity'),
#  (0.0025559933329937627, 'Medication_History'),
#  (0.0024572847075286165, 'Moderate Activity'),
#  (0.0023060201495499586, 'Diabetic'),
#  (0.002229206137553552, 'Mediterranean Diet'),
#  (0.002208718796627669, 'Gender'),
#  (0.0021768854133982357, 'Primary School'),
#  (0.002093429651637288, 'Secondary School'),
#  (0.002014601449133087, 'Balanced Diet'),
#  (0.0018812449386884221, 'Low-Carb Diet'),
#  (0.0018428356030009013, 'Sedentary'),
#  (0.0018289222709435803, 'Heart Disease')]

# %%
# Visualize the features by importance
importances_df = pd.DataFrame(sorted(zip(rf_model.feature_importances_, X.columns), reverse=True))
importances_df.set_index(importances_df[1], inplace=True)
importances_df.drop(columns=1, inplace=True)
importances_df.rename(columns={0: 'Feature Importances'}, inplace=True)
importances_sorted = importances_df.sort_values(by='Feature Importances').head(10)
importances_sorted.plot(kind='barh', color='lightgreen', title= 'Features Importances', legend=False)
# Out:
# <Axes: title={'center': 'Features Importances'}, ylabel='1'>
